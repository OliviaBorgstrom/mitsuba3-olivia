# %%
import numpy as np
import xml.etree.ElementTree as ET
import mitsuba as mi
import matplotlib.pyplot as plt
import pandas as pd
import random
# Out:
# /var/folders/9b/mcbx_6tn6nb1kp3f2hvw7hz40000gn/T/ipykernel_44702/1577095553.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import mitsuba as mi

mi.set_variant('scalar_rgb')

# Create an alias for convenience
#from mitsuba import ScalarTransform4f as T

scenedict = {
    'type': 'scene',
    #'light': {'type': 'constant'},
    'integrator': {
        'type': 'ptracer',
        'max_depth': 65,
        'hide_emitters': False,
        },
    
    'sensor': { 
        'type': 'perspective',
        'fov': 100,
        'to_world': mi.ScalarTransform4f.look_at(origin=[0, 1100, 792],
                             target=[0, 1500, 1120],
                             up=[0,0,1]),
        'sampler': {
            'type': 'independent',
            'sample_count': 32,
        },
        'film': {
            'type': 'hdrfilm',
            'width': 1024,
            'height': 1024,
            'file_format': 'openexr',
            'pixel_format': 'rgb',
            'component_format': 'uint32',
            'rfilter' : {
                'type': 'tent',
            },
        },
    },

    'MirrorBSDF' : {
        'type' : 'twosided',
        'material' : {
                'type': 'conductor',
            },
    },
    
    'test' : {
        'type' : 'twosided',
        'material' : {
            'type' : 'diffuse',
            'reflectance' : {
                'type' : 'rgb',
                'value' : [0.5,0.5,1],
            }
        }
    },
    
    'mirror_spherical' : {
        'type': 'cube',
        'to_world' : mi.ScalarTransform4f.scale([1500,650,33]).look_at(origin=[0, 2000, 355],
                             target=[0,1000,600],
                             up=[0,0,1]),
        'bsdf' : {
            'type' : 'ref',
            'id' : 'MirrorBSDF',
        }
    },
    
    'mirror_flat' : {
        'type': 'cube',
        'to_world' : mi.ScalarTransform4f.scale([740,440,0.1]).look_at(origin=[0, 1000, 710],
                             target=[0,2000,900],
                             up=[0,0,1]),
        'bsdf' : {
            'type' : 'ref',
            'id' : 'MirrorBSDF',
        }
    },
    
    'detector' : {
        'type': 'rectangle',
        'to_world' : mi.ScalarTransform4f.scale([1000,500,0.5]).look_at(origin=[0, 1500, 1120],
                             target=[0,1000,710],
                             up=[0,0,1]),
        'bsdf' : {
            'type' : 'ref',
            'id' : 'test',
        }
    },
    
    'backwall' : {
        'type': 'rectangle',
        'to_world' : mi.ScalarTransform4f.scale([3000,3000,1]).look_at(origin=[-1000, 1500, 500],  #1 or 0 for z scale ??
                             target=[0,1500,500],
                             up=[0,1,0]),
        'bsdf' : {
            'type' : 'diffuse',
            'reflectance' : {
                'type' : 'rgb',
                'value' : [0.4, 1, 0.2],
             }
        }
    },
    
    'ceiling' : {
        'type': 'rectangle',
        'to_world' : mi.ScalarTransform4f.scale([3000,3000,1]).look_at(origin=[0, 1500, 3000], #1 or 0 for z scale ??
                             target=[0,1500,0],
                             up=[0,1,0]),
        'bsdf' : {
            'type' : 'diffuse',
            'reflectance' : {
                'type' : 'rgb',
                'value' : [0.8, 0.3, 0.45],
             }
        }
    },
    
    'leftwall' : {
        'type': 'rectangle',
        'to_world' : mi.ScalarTransform4f.scale([3000,3000,3000]).look_at(origin=[0, 0, 500],
                             target=[0,1500,500],
                             up=[0,0,1]),
        'bsdf' : {
            'type' : 'diffuse',
            'reflectance' : {
                'type' : 'rgb',
                'value' : [0.32, 0.46, 0.23],
             }
        }
    },
    
    'rightwall' : {
        'type': 'rectangle',
        'to_world' : mi.ScalarTransform4f.scale([3000,3000,3000]).look_at(origin=[0, 3000, 500],
                             target=[0,1500,500],
                             up=[0,0,1]),
        'bsdf' : {
            'type' : 'diffuse',
            'reflectance' : {
                'type' : 'rgb',
                'value' : [0.92, 0.58, 1],
             }
        }
    },
    
    'floor' : {
        'type': 'rectangle',
        'to_world' : mi.ScalarTransform4f.scale([3000,3000,3000]).look_at(origin=[0, 1500, -1000],
                             target=[0,1500,3000],
                             up=[0,1,0]),
        'bsdf' : {
            'type' : 'diffuse',
            'reflectance' : {
                'type' : 'rgb',
                'value' : [0.56, 0.23, 0.54],
             }
        }
    },
}

# %%
nm_per_ev_constant = (float(6.6260715e-34)*float(3.00e8)*float(1e9))/(float(1.6021e-19)*float(1e6))

# %%
#Values for linear interpolation.
wavelength_steps = [100, 200, 230, 270, 300, 330, 370, 400, 430, 470, 500, 530, 570, 600, 630, 670, 700, 1000]
qe_steps = [0, 0, 0.02, 0.20, 0.31, 0.35, 0.35, 0.33, 0.31, 0.24, 0.18, 0.08, 0.05, 0.02, 0.01, 0.002, 0, 0]
rows_to_drop =[]

#load data from original G4 output (csv format)
column_names = ["time (ps)", "x", "y", "z", "px", "py", "pz", "E (MeV)"]
photon_data_full = pd.read_csv('photons_with_wavelength.csv', names = column_names)
initial_number_of_photons = photon_data_full.count()[0]

def ev_to_nm (energy):
    return nm_per_ev_constant/energy

#gives linear relation between two wavelegths thanks to two efficiency values
def linear_interp (j,w_input):
    a = (qe_steps[j] - qe_steps[j-1])/(wavelength_steps[j] - wavelength_steps[j-1])
    b = qe_steps[j-1] - a*wavelength_steps[j-1]
    return a*w_input+b

#Convert energy column to wavelength in nm.
photon_data_full['E (MeV)'] = photon_data_full['E (MeV)'].apply(ev_to_nm)
photon_data_full.rename(columns={"E (MeV)": "Wavelength (nm)"}, inplace = True)

#iterate over each photon.
for i in range(initial_number_of_photons):
    for j in range(len(wavelength_steps)):
        #find index in wavelength_steps corresponding to the photon.
        if photon_data_full.loc[i, 'Wavelength (nm)']<wavelength_steps[j]:
            break
    #Use linear interpolation to calculate QE at this wavelength.
    qe_estimated = linear_interp(j, photon_data_full.loc[i, 'Wavelength (nm)']) 
    x = random.uniform(0, 1)
    if x > qe_estimated:
        rows_to_drop.append(i)

#generate new frame only with photons that will be detected.
photon_detected = photon_data_full.drop(rows_to_drop)
#I don't know why a first column is created and keeps track of the old index of photons.
photon_detected.reset_index(drop=True, inplace= True)

#Can be removed later. Outputs characteristics of saved photons.
photon_detected.to_csv('./photons_detected_spectral.csv' )
final_number_of_photons = photon_detected.count()[0]
fraction_detected = final_number_of_photons/initial_number_of_photons
print ("{0:.4} of emitted photon in G4 are actually detected.".format(fraction_detected))
# Out:
# 0.1482 of emitted photon in G4 are actually detected.
# /var/folders/9b/mcbx_6tn6nb1kp3f2hvw7hz40000gn/T/ipykernel_44702/3880959156.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   initial_number_of_photons = photon_data_full.count()[0]
# /var/folders/9b/mcbx_6tn6nb1kp3f2hvw7hz40000gn/T/ipykernel_44702/3880959156.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   final_number_of_photons = photon_detected.count()[0]

# %%
x_position = photon_detected.values[:,1] # x position of the detector
y_position = photon_detected.values[:,2] # y position of the detectore
z_position = photon_detected.values[:,3] # z position of the detector
x_momentum = photon_detected.values[:,4] # x momentum of the particle
y_momentum = photon_detected.values[:,5] # y momentum of the particle
z_momentum = photon_detected.values[:,6] # z momentum of the particle

# calculate the target coordinates for each photons
x_target = []
y_target = []
z_target = []
for i in range(len(x_position)):
    x_target.append(x_position[i] + x_momentum[i])
    y_target.append(y_position[i] + y_momentum[i])
    z_target.append(z_position[i] + z_momentum[i])

# %%
tree = ET.parse('base_geometry.xml')
root = tree.getroot()
for emitter in root.iter('emitter'):
    print(emitter.attrib)

# %%
# parse the xml file to get information from the 1st mirror
tree = ET.parse('base_geometry.xml')
root = tree.getroot()
for shape in root.iter('shape'):
    if shape.get('id') == 'mirror_spherical':
        for lookat in shape.iter('lookat'):
            # get mirror's position
            x_mirror = float(lookat.get('origin').split(',')[0])
            y_mirror = float(lookat.get('origin').split(',')[1])
            z_mirror = float(lookat.get('origin').split(',')[2])
            # get mirror's target i.e. the vector normal to the mirror plane
            x_target_mirror = float(lookat.get('target').split(',')[0])
            y_target_mirror = float(lookat.get('target').split(',')[1])
            z_target_mirror = float(lookat.get('target').split(',')[2])

print(x_mirror, y_mirror, z_mirror)
print(x_target_mirror, y_target_mirror, z_target_mirror)
# add a check when spherical mirror is not present
# Out:
# 0.0 2000.0 355.0
# 0.0 1000.0 600.0

# %%
# calculate the intersection between of line and a plane
def isect_line_plane_v3(point_1, point_2, plane_coord, plane_normal, epsilon=1e-6):
    """
    point_1, point_2: Define the line.
    plane_coord, plane_normal: define the plane:
        plane_coord Is a point on the plane (plane coordinate).
        plane_normal Is a normal vector defining the plane direction;

    Return a Vector or None (when the intersection can't be found).
    """
    u = np.array(point_2) - np.array(point_1)
    dot = np.dot(np.array(plane_normal), np.array(u))

    if abs(dot) > epsilon:
        # The factor of the point between p0 -> p1 (0 - 1)
        # if 'fac' is between (0 - 1) the point intersects with the segment.
        # Otherwise:
        #  < 0.0: behind p0.
        #  > 1.0: infront of p1.
        w = np.array(point_1) - np.array(plane_coord)
        
        factor = - np.dot(np.array(plane_normal), np.array(w)) / dot
        u = factor * u
        return point_1 + u

    # The segment is parallel to plane.
    return None

intersection = []
distance = []
mirror_coord = [x_mirror, y_mirror, z_mirror]
mirror_normal = [x_target_mirror, y_target_mirror, z_target_mirror]
for i in range(len(x_position)):
    point_1 = [x_position[i], y_position[i], z_position[i]]
    point_2 = [x_target[i], y_target[i], z_target[i]]
    intersection.append(isect_line_plane_v3(point_1, point_2, mirror_coord, mirror_normal, epsilon=1e-6))
    distance.append(np.sqrt((x_position[i] - intersection[i][0])**2 + (y_position[i] - intersection[i][1])**2 + (z_position[i] - intersection[i][2])**2))
print(distance)
# Out:
# [2279.2089626119096, 1963.1274116973664, 2217.2400547135717, 1973.42812766221, 2014.1452748480335, 2086.522606754465, 2045.920199647601, 2181.636625388566, 2287.320751844475, 1900.5329598328942, 2059.1328933774435, 2276.4397446252847, 2004.262622303323, 2049.6432224212945, 1853.2745229030395, 2016.896859384199, 1980.6471060886738, 2003.6237906655824, 1875.1354884595457, 1783.6490659866627, 1778.6292536080311, 1954.618596179496, 1756.919623458563, 1857.8712930498841, 1749.1636553274952, 1577.5965035036568, 1211.045382452787, 1727.5572834386514, 1461.7002031309567, 1709.0858663779234, 1348.3192237222954, 1327.5578679211444, 1583.9309022370728, 1421.3558090566294, 1640.2614763209476, 1283.9396253161456, 1272.781464214127, 1516.7966147552022, 1647.581344572413, 1574.5566614310187, 1679.4383465775475, 1465.95413187704, 1231.6732176603832, 1734.8627761345572, 1371.5877473126254, 1455.4773475641655, 1621.8025083882396, 1366.5217507383973, 1782.87762608073, 1612.182579543508, 1321.817129924338, 1652.236310671743, 1556.589959082512, 1517.1982050641777, 1313.4958826183201, 1324.931963091634, 1406.860501367914, 1716.615799880161, 1259.472486754451, 1494.0274598998683, 1543.9965656985726, 1841.2246468705343, 1289.5916137941058, 1291.243296171947, 1378.3486912868714, 1290.9449984028781, 1837.8647622755436, 1281.5649592821833, 1511.4965308467238, 1182.9230387545558, 1676.6811382784629, 1731.6528364521598, 1255.8272931491426, 1318.9397198417153, 1178.826009599456, 1264.5972039324024, 1252.046098603248, 1231.0556808323913, 1131.5288606261704, 1323.1917436272374, 1286.6105452129568, 1251.920492838597, 1149.146551038845, 1164.1382955554843, 1178.7738413011414, 1040.4650631120285, 1151.1699478509272, 939.2859662391247, 950.2558887257225, 924.7742668830991, 1083.3431275923156, 894.4576396121087, 855.1767444161841, 898.7947631905041, 993.8520916081145]

# %%
# # calculate the distance between the photons and the mirror
# distance = []
# for i in range(len(x_position)):
#     distance.append(np.sqrt((x_position[i] - x_mirror)**2 + (y_position[i] - y_mirror)**2 + (z_position[i] - z_mirror)**2))
# calculate the cutoff angle for each spot light
cutoff_angle = np.array(2 * np.arctan(100/np.array(distance))) # should give a cutoff angle of around 0.2 degrees
print(len(cutoff_angle))
# Out:
# 95

# %%
# function that adds a new emitter with coordinated and target
def add_photon_emitter(x, z, y, x_target, z_target, y_target, cutoff_angle):

    for i in range(len(x)):
        name = "photon" + str(i)
        scenedict[name] = {'type' : 'photon_emitter_olivia',
                           'to_world' : mi.ScalarTransform4f.look_at(origin=[x[i], z[i], y[i]], 
                                                  target= [x_target[i],z_target[i],y_target[i]],
                                                  up=[0, 1, 0])
                          }

def add_spot_emitter(x, z, y, x_target, z_target, y_target, cutoff_angle):

    for i in range(len(x)):
        name = "spot" + str(i)
        scenedict[name] = {'type' : 'spot',
                           'to_world' : mi.ScalarTransform4f.look_at(origin=[x[i], z[i], y[i]], 
                                                  target= [x_target[i],z_target[i],y_target[i]],
                                                  up=[0, 1, 0]),
                           'intensity' : {'type': 'spectrum', 'value': 2000 },#200000000},
                           'cutoff_angle' : 1,#cutoff_angle[i],
                          }

# add photon emitters
#add_photon_emitter(x_position, z_position, y_position, x_target, z_target, y_target, cutoff_angle)
add_spot_emitter(x_position, z_position, y_position, x_target, z_target, y_target, cutoff_angle)

# %%
scenedict
# Out:
# {'type': 'scene',
#  'integrator': {'type': 'ptracer', 'max_depth': 65, 'hide_emitters': False},
#  'sensor': {'type': 'perspective',
#   'fov': 100,
#   'to_world': [[-1, 0, 0, 0],
#    [0, -0.63408, 0.773268, 1100],
#    [0, 0.773268, 0.63408, 792],
#    [0, 0, 0, 1]],
#   'sampler': {'type': 'independent', 'sample_count': 32},
#   'film': {'type': 'hdrfilm',
#    'width': 1024,
#    'height': 1024,
#    'file_format': 'openexr',
#    'pixel_format': 'rgb',
#    'component_format': 'uint32',
#    'rfilter': {'type': 'tent'}}},
#  'MirrorBSDF': {'type': 'twosided', 'material': {'type': 'conductor'}},
#  'test': {'type': 'twosided',
#   'material': {'type': 'diffuse',
#    'reflectance': {'type': 'rgb', 'value': [0.5, 0.5, 1]}}},
#  'mirror_spherical': {'type': 'cube',
#   'to_world': [[1500, 0, 0, 0],
#    [0, 154.675, -631.328, 1.3e+06],
#    [0, 32.0521, 7.85275, 11715],
#    [0, 0, 0, 1]],
#   'bsdf': {'type': 'ref', 'id': 'MirrorBSDF'}},
#  'mirror_flat': {'type': 'cube',
#   'to_world': [[-740, 0, 0, 0],
#    [0, -82.1307, 432.267, 440000],
#    [0, 0.0982425, 0.0186661, 71],
#    [0, 0, 0, 1]],
#   'bsdf': {'type': 'ref', 'id': 'MirrorBSDF'}},
#  'detector': {'type': 'rectangle',
#   'to_world': [[1000, 0, 0, 0],
#    [0, -317.04, -386.634, 750000],
#    [0, 0.386634, -0.31704, 560],
#    [0, 0, 0, 1]],
#   'bsdf': {'type': 'ref', 'id': 'test'}},
#  'backwall': {'type': 'rectangle',
#   'to_world': [[0, 0, 3000, -3e+06],
#    [0, 3000, 0, 4.5e+06],
#    [-1, 0, 0, 500],
#    [0, 0, 0, 1]],
#   'bsdf': {'type': 'diffuse',
#    'reflectance': {'type': 'rgb', 'value': [0.4, 1, 0.2]}}},
#  'ceiling': {'type': 'rectangle',
#   'to_world': [[-3000, 0, 0, 0],
#    [0, 3000, 0, 4.5e+06],
#    [0, 0, -1, 3000],
#    [0, 0, 0, 1]],
#   'bsdf': {'type': 'diffuse',
#    'reflectance': {'type': 'rgb', 'value': [0.8, 0.3, 0.45]}}},
#  'leftwall': {'type': 'rectangle',
#   'to_world': [[-3000, 0, 0, 0],
#    [0, 0, 3000, 0],
#    [0, 3000, 0, 1.5e+06],
#    [0, 0, 0, 1]],
#   'bsdf': {'type': 'diffuse',
#    'reflectance': {'type': 'rgb', 'value': [0.32, 0.46, 0.23]}}},
#  'rightwall': {'type': 'rectangle',
#   'to_world': [[3000, 0, 0, 0],
#    [0, 0, -3000, 9e+06],
#    [0, 3000, 0, 1.5e+06],
#    [0, 0, 0, 1]],
#   'bsdf': {'type': 'diffuse',
#    'reflectance': {'type': 'rgb', 'value': [0.92, 0.58, 1]}}},
#  'floor': {'type': 'rectangle',
#   'to_world': [[3000, 0, 0, 0],
#    [0, 3000, 0, 4.5e+06],
#    [0, 0, 3000, -3e+06],
#    [0, 0, 0, 1]],
#   'bsdf': {'type': 'diffuse',
#    'reflectance': {'type': 'rgb', 'value': [0.56, 0.23, 0.54]}}},
#  'spot0': {'type': 'spot',
#   'to_world': [[0.875377, -0.482196, 0.0346827, -0.0779061],
#    [0, 0.0717412, 0.997423, 1008.46],
#    [-0.483441, -0.873121, 0.0628006, 100.792],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot1': {'type': 'spot',
#   'to_world': [[0.990867, 0.133352, -0.0199829, -0.113022],
#    [-0, 0.148196, 0.988958, 1085.58],
#    [0.134841, -0.979926, 0.146842, 108.496],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot2': {'type': 'spot',
#   'to_world': [[0.861929, 0.505503, -0.0393071, -0.0991319],
#    [-0, 0.0775243, 0.99699, 1055.08],
#    [0.507028, -0.859335, 0.0668205, 105.449],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot3': {'type': 'spot',
#   'to_world': [[0.995588, 0.0927803, -0.0139878, -0.106138],
#    [-0, 0.149078, 0.988825, 1070.46],
#    [0.0938288, -0.984463, 0.14842, 106.986],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot4': {'type': 'spot',
#   'to_world': [[0.985596, -0.167316, 0.0246027, -0.0926797],
#    [0, 0.14548, 0.989361, 1040.91],
#    [-0.169115, -0.975111, 0.143384, 104.033],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot5': {'type': 'spot',
#   'to_world': [[0.875061, -0.482902, 0.0327604, -0.165425],
#    [0, 0.067685, 0.997707, 1200.65],
#    [-0.484012, -0.873055, 0.0592285, 119.992],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot6': {'type': 'spot',
#   'to_world': [[0.855037, 0.516475, -0.0465346, -0.160895],
#    [-0, 0.0897369, 0.995965, 1190.71],
#    [0.518567, -0.851587, 0.0767283, 118.999],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot7': {'type': 'spot',
#   'to_world': [[0.863633, 0.501774, -0.0485996, -0.0926112],
#    [-0, 0.0964044, 0.995342, 1040.76],
#    [0.504122, -0.85961, 0.083258, 104.018],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot8': {'type': 'spot',
#   'to_world': [[0.9701, 0.242387, -0.0124459, -0.0927042],
#    [-0, 0.0512798, 0.998684, 1040.96],
#    [0.242706, -0.968824, 0.0497466, 104.039],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot9': {'type': 'spot',
#   'to_world': [[0.991033, 0.132149, -0.0197664, -0.143441],
#    [-0, 0.147931, 0.988998, 1152.38],
#    [0.133619, -0.980129, 0.146604, 115.169],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot10': {'type': 'spot',
#   'to_world': [[0.854054, 0.518323, -0.0439718, -0.160807],
#    [-0, 0.0845311, 0.996421, 1190.52],
#    [0.520185, -0.850997, 0.0721941, 118.979],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot11': {'type': 'spot',
#   'to_world': [[0.908278, -0.417585, 0.0255615, -0.0892854],
#    [0, 0.0610982, 0.998132, 1033.45],
#    [-0.418367, -0.906581, 0.0554942, 103.289],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot12': {'type': 'spot',
#   'to_world': [[0.917266, -0.395293, 0.0486379, -0.135851],
#    [0, 0.122122, 0.992515, 1135.71],
#    [-0.398274, -0.910401, 0.112018, 113.504],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot13': {'type': 'spot',
#   'to_world': [[0.913936, -0.402842, 0.049395, -0.115968],
#    [0, 0.121705, 0.992566, 1092.05],
#    [-0.405859, -0.907142, 0.11123, 109.142],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot14': {'type': 'spot',
#   'to_world': [[0.92348, -0.380627, 0.0480472, -0.203018],
#    [0, 0.125238, 0.992127, 1279.35],
#    [-0.383647, -0.916209, 0.115655, 127.838],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot15': {'type': 'spot',
#   'to_world': [[0.862186, -0.504971, 0.0404874, -0.183927],
#    [0, 0.0799212, 0.996801, 1239.77],
#    [-0.506591, -0.859428, 0.068907, 123.893],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot16': {'type': 'spot',
#   'to_world': [[0.852323, 0.521187, -0.0437099, -0.197672],
#    [-0, 0.0835728, 0.996502, 1268.27],
#    [0.523016, -0.849341, 0.071231, 126.733],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot17': {'type': 'spot',
#   'to_world': [[0.896312, 0.442542, -0.0279599, -0.206138],
#    [-0, 0.0630545, 0.99801, 1285.82],
#    [0.443424, -0.894528, 0.0565165, 128.482],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot18': {'type': 'spot',
#   'to_world': [[0.866293, -0.497144, 0.0488318, -0.237219],
#    [0, 0.0977543, 0.995211, 1335.2],
#    [-0.499536, -0.862144, 0.0846838, 133.392],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot19': {'type': 'spot',
#   'to_world': [[0.962737, -0.26786, 0.0372516, -0.220717],
#    [0, 0.137745, 0.990468, 1309.44],
#    [-0.270438, -0.95356, 0.132613, 130.831],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot20': {'type': 'spot',
#   'to_world': [[0.984475, -0.173663, 0.0254918, -0.208204],
#    [0, 0.145232, 0.989398, 1289.9],
#    [-0.175524, -0.974037, 0.142977, 128.889],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot21': {'type': 'spot',
#   'to_world': [[0.897965, -0.4392, 0.0276154, -0.235298],
#    [0, 0.0627527, 0.998029, 1332.2],
#    [-0.440067, -0.896195, 0.0563497, 133.094],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot22': {'type': 'spot',
#   'to_world': [[0.98639, -0.162678, 0.0238686, -0.222503],
#    [0, 0.145168, 0.989407, 1312.23],
#    [-0.16442, -0.975942, 0.143192, 131.108],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot23': {'type': 'spot',
#   'to_world': [[0.88623, -0.460441, 0.0508992, -0.227687],
#    [0, 0.109875, 0.993945, 1320.32],
#    [-0.463246, -0.880864, 0.0973744, 131.913],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot24': {'type': 'spot',
#   'to_world': [[0.990215, -0.138042, 0.0204533, -0.224819],
#    [0, 0.146567, 0.989201, 1315.84],
#    [-0.139549, -0.979522, 0.145133, 131.467],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot25': {'type': 'spot',
#   'to_world': [[0.927265, 0.371339, -0.0478342, -0.416973],
#    [-0, 0.12776, 0.991805, 1553.58],
#    [0.374407, -0.919666, 0.118467, 155.155],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot26': {'type': 'spot',
#   'to_world': [[0.993908, -0.108994, 0.0163373, -0.704126],
#    [0, 0.148236, 0.988952, 1880.4],
#    [-0.110212, -0.982928, 0.147333, 187.749],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot27': {'type': 'spot',
#   'to_world': [[0.857001, 0.51284, -0.0504396, -0.353232],
#    [-0, 0.0978813, 0.995198, 1481.03],
#    [0.515314, -0.852886, 0.0838844, 147.92],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot28': {'type': 'spot',
#   'to_world': [[0.906833, -0.418511, 0.050036, -0.539437],
#    [0, 0.118712, 0.992929, 1692.96],
#    [-0.421491, -0.90042, 0.107652, 169.056],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot29': {'type': 'spot',
#   'to_world': [[0.884112, -0.464595, 0.0499767, -0.347304],
#    [0, 0.106953, 0.994264, 1474.29],
#    [-0.467275, -0.879041, 0.0945588, 147.247],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot30': {'type': 'spot',
#   'to_world': [[0.856431, 0.51404, -0.0478469, -0.684647],
#    [-0, 0.0926796, 0.995696, 1858.23],
#    [0.516262, -0.852745, 0.0793737, 185.538],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot31': {'type': 'spot',
#   'to_world': [[0.857303, 0.513332, -0.0390223, -0.724833],
#    [-0, 0.075799, 0.997123, 1903.97],
#    [0.514813, -0.854836, 0.0649827, 190.1],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot32': {'type': 'spot',
#   'to_world': [[0.904723, -0.423114, 0.0495145, -0.436086],
#    [0, 0.116231, 0.993222, 1575.33],
#    [-0.426001, -0.898591, 0.105157, 157.325],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot33': {'type': 'spot',
#   'to_world': [[0.998938, -0.0455555, 0.00688774, -0.505117],
#    [0, 0.149495, 0.988762, 1653.9],
#    [-0.0460733, -0.987712, 0.149337, 165.16],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot34': {'type': 'spot',
#   'to_world': [[0.998193, -0.0600193, 0.0029285, -0.495963],
#    [0, 0.0487347, 0.998812, 1643.48],
#    [-0.0600907, -0.997007, 0.0486466, 164.121],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot35': {'type': 'spot',
#   'to_world': [[0.915656, -0.399014, 0.0486033, -0.691754],
#    [0, 0.120915, 0.992663, 1866.32],
#    [-0.401963, -0.908938, 0.110716, 186.345],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot36': {'type': 'spot',
#   'to_world': [[0.909607, 0.412353, -0.0507906, -0.701048],
#    [-0, 0.122249, 0.9925, 1876.9],
#    [0.415469, -0.902785, 0.111198, 187.4],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot37': {'type': 'spot',
#   'to_world': [[0.986291, 0.164816, -0.00816949, -0.596118],
#    [-0, 0.0495066, 0.998774, 1757.47],
#    [0.165018, -0.985081, 0.0488279, 175.489],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot38': {'type': 'spot',
#   'to_world': [[0.99469, 0.101762, -0.0153458, -0.296212],
#    [-0, 0.149115, 0.98882, 1416.14],
#    [0.102913, -0.98357, 0.148323, 141.448],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot39': {'type': 'spot',
#   'to_world': [[0.878537, -0.476535, 0.0329762, -0.527115],
#    [0, 0.0690348, 0.997614, 1678.94],
#    [-0.477675, -0.876441, 0.0606497, 167.657],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot40': {'type': 'spot',
#   'to_world': [[0.884284, -0.464239, 0.050251, -0.37184],
#    [0, 0.107615, 0.994193, 1502.21],
#    [-0.46695, -0.879148, 0.0951624, 150.032],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot41': {'type': 'spot',
#   'to_world': [[0.925034, 0.376748, -0.0487229, -0.516771],
#    [-0, 0.128257, 0.991741, 1667.16],
#    [0.379885, -0.917394, 0.118642, 166.483],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot42': {'type': 'spot',
#   'to_world': [[0.945389, 0.323016, -0.0435986, -0.715296],
#    [-0, 0.13376, 0.991014, 1893.12],
#    [0.325945, -0.936893, 0.126456, 189.017],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot43': {'type': 'spot',
#   'to_world': [[0.854054, 0.518764, -0.0384002, -0.389653],
#    [-0, 0.0738204, 0.997272, 1522.49],
#    [0.520184, -0.851724, 0.0630466, 152.054],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot44': {'type': 'spot',
#   'to_world': [[0.999725, -0.0231727, 0.00350985, -0.550945],
#    [0, 0.149757, 0.988723, 1706.06],
#    [-0.023437, -0.988451, 0.149715, 170.362],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot45': {'type': 'spot',
#   'to_world': [[0.990749, 0.134216, -0.020052, -0.478397],
#    [-0, 0.147761, 0.989023, 1623.49],
#    [0.135705, -0.979874, 0.146394, 162.127],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot46': {'type': 'spot',
#   'to_world': [[0.97812, -0.205891, 0.0298201, -0.335698],
#    [0, 0.143339, 0.989674, 1461.08],
#    [-0.208039, -0.96802, 0.140203, 145.93],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot47': {'type': 'spot',
#   'to_world': [[0.923677, 0.380021, -0.0490289, -0.606579],
#    [-0, 0.127956, 0.99178, 1769.38],
#    [0.383171, -0.916085, 0.11819, 176.677],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot48': {'type': 'spot',
#   'to_world': [[0.983314, -0.181691, 0.00900214, -0.379996],
#    [0, 0.0494858, 0.998775, 1511.49],
#    [-0.181914, -0.98211, 0.0486601, 150.958],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot49': {'type': 'spot',
#   'to_world': [[0.969664, 0.244119, -0.0125363, -0.516787],
#    [-0, 0.0512855, 0.998684, 1667.18],
#    [0.244441, -0.968388, 0.0497297, 166.485],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot50': {'type': 'spot',
#   'to_world': [[0.989721, 0.141456, -0.0210472, -0.603696],
#    [-0, 0.14717, 0.989111, 1766.1],
#    [0.143013, -0.978944, 0.145657, 176.35],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot51': {'type': 'spot',
#   'to_world': [[0.953191, -0.299621, 0.0406664, -0.331003],
#    [0, 0.134493, 0.990915, 1455.73],
#    [-0.302368, -0.944531, 0.128198, 145.397],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot52': {'type': 'spot',
#   'to_world': [[0.912271, -0.408865, 0.0243015, -0.554021],
#    [0, 0.0593318, 0.998238, 1709.56],
#    [-0.409586, -0.910664, 0.0541267, 170.711],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot53': {'type': 'spot',
#   'to_world': [[0.999029, -0.0435745, 0.00657955, -0.416074],
#    [0, 0.149303, 0.988792, 1552.56],
#    [-0.0440684, -0.987831, 0.149158, 155.053],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot54': {'type': 'spot',
#   'to_world': [[0.981178, -0.191103, 0.0277456, -0.618653],
#    [0, 0.14368, 0.989624, 1783.12],
#    [-0.193107, -0.970997, 0.140976, 178.047],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot55': {'type': 'spot',
#   'to_world': [[0.959329, 0.279563, -0.0391388, -0.620614],
#    [-0, 0.138648, 0.990342, 1785.35],
#    [0.282289, -0.950064, 0.133009, 178.27],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot56': {'type': 'spot',
#   'to_world': [[0.97125, -0.235692, 0.0335162, -0.539545],
#    [0, 0.140787, 0.99004, 1693.08],
#    [-0.238063, -0.961576, 0.136739, 169.068],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot57': {'type': 'spot',
#   'to_world': [[0.865605, -0.498609, 0.0460071, -0.371233],
#    [0, 0.0918805, 0.99577, 1501.52],
#    [-0.500727, -0.861944, 0.0795322, 149.963],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot58': {'type': 'spot',
#   'to_world': [[0.93201, -0.359448, 0.0464226, -0.700617],
#    [0, 0.128086, 0.991763, 1876.41],
#    [-0.362434, -0.924333, 0.119377, 187.351],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot59': {'type': 'spot',
#   'to_world': [[0.871952, -0.487186, 0.0484657, -0.54848],
#    [0, 0.0989922, 0.995088, 1703.25],
#    [-0.489591, -0.867669, 0.0863165, 170.082],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot60': {'type': 'spot',
#   'to_world': [[0.997661, 0.0675839, -0.0102303, -0.390827],
#    [-0, 0.149668, 0.988736, 1523.82],
#    [0.0683538, -0.986424, 0.149318, 152.187],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot61': {'type': 'spot',
#   'to_world': [[0.875382, 0.482312, -0.0328896, -0.308797],
#    [-0, 0.0680334, 0.997683, 1430.46],
#    [0.483433, -0.873353, 0.0595552, 142.876],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot62': {'type': 'spot',
#   'to_world': [[0.888481, 0.456, -0.0516231, -0.703222],
#    [-0, 0.11249, 0.993653, 1879.37],
#    [0.458913, -0.882842, 0.0999451, 187.647],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot63': {'type': 'spot',
#   'to_world': [[0.990008, -0.139486, 0.0206869, -0.632665],
#    [0, 0.146703, 0.989181, 1799.07],
#    [-0.141012, -0.979297, 0.145237, 179.638],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot64': {'type': 'spot',
#   'to_world': [[0.847053, 0.529489, -0.0462828, -0.668307],
#    [-0, 0.0870783, 0.996202, 1839.63],
#    [0.531508, -0.843836, 0.0737599, 183.683],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot65': {'type': 'spot',
#   'to_world': [[0.862145, 0.504132, -0.0505757, -0.72323],
#    [-0, 0.0998214, 0.995005, 1902.14],
#    [0.506662, -0.857839, 0.0860605, 189.918],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot66': {'type': 'spot',
#   'to_world': [[0.858078, 0.511359, -0.0470494, -0.270224],
#    [-0, 0.0916216, 0.995794, 1386.56],
#    [0.513519, -0.854469, 0.0786185, 138.498],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot67': {'type': 'spot',
#   'to_world': [[0.972866, 0.228994, -0.0330696, -0.6511],
#    [-0, 0.14293, 0.989733, 1820.05],
#    [0.23137, -0.962877, 0.139051, 181.73],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot68': {'type': 'spot',
#   'to_world': [[0.869614, -0.491351, 0.0484309, -0.535333],
#    [0, 0.0980915, 0.995177, 1688.29],
#    [-0.493732, -0.86542, 0.0853018, 168.59],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot69': {'type': 'spot',
#   'to_world': [[0.999353, -0.0355507, 0.00539272, -0.726726],
#    [0, 0.149975, 0.98869, 1906.12],
#    [-0.0359574, -0.98805, 0.149878, 190.314],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot70': {'type': 'spot',
#   'to_world': [[0.884463, 0.465599, -0.0307116, -0.447463],
#    [-0, 0.0658184, 0.997832, 1588.28],
#    [0.466611, -0.882545, 0.058214, 158.616],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot71': {'type': 'spot',
#   'to_world': [[0.862069, 0.505372, -0.0378819, -0.389373],
#    [-0, 0.0747486, 0.997203, 1522.17],
#    [0.50679, -0.859658, 0.0644385, 152.022],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot72': {'type': 'spot',
#   'to_world': [[0.853188, 0.519922, -0.0418459, -0.764827],
#    [-0, 0.0802256, 0.996777, 1966.12],
#    [0.521603, -0.850438, 0.0684475, 196.301],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot73': {'type': 'spot',
#   'to_world': [[0.884547, -0.465478, 0.0301095, -0.740809],
#    [0, 0.0645503, 0.997914, 1926.09],
#    [-0.46645, -0.882703, 0.0570978, 192.307],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot74': {'type': 'spot',
#   'to_world': [[0.989907, 0.14018, -0.0208469, -0.735476],
#    [-0, 0.147097, 0.989122, 1917.21],
#    [0.141722, -0.979138, 0.145613, 191.42],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot75': {'type': 'spot',
#   'to_world': [[0.867208, 0.495388, -0.0504132, -0.740075],
#    [-0, 0.101242, 0.994862, 1924.87],
#    [0.497946, -0.862752, 0.0877981, 192.185],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot76': {'type': 'spot',
#   'to_world': [[0.995108, 0.0986756, -0.00480777, -0.78715],
#    [-0, 0.0486653, 0.998815, 2003.32],
#    [0.0987926, -0.993929, 0.0484272, 200.014],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot77': {'type': 'spot',
#   'to_world': [[0.987455, 0.157704, -0.00788828, -0.797918],
#    [-0, 0.049957, 0.998751, 2021.27],
#    [0.157901, -0.986222, 0.0493303, 201.805],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot78': {'type': 'spot',
#   'to_world': [[0.939535, 0.339418, -0.0454914, -0.784467],
#    [-0, 0.13284, 0.991138, 1998.85],
#    [0.342453, -0.931208, 0.124808, 199.568],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot79': {'type': 'spot',
#   'to_world': [[0.940292, 0.339859, -0.0186299, -0.744418],
#    [-0, 0.0547342, 0.998501, 1932.11],
#    [0.34037, -0.938882, 0.0514661, 192.907],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot80': {'type': 'spot',
#   'to_world': [[0.994492, 0.104685, -0.0051574, -0.767436],
#    [-0, 0.0492064, 0.998789, 1970.47],
#    [0.104812, -0.993288, 0.0489354, 196.735],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot81': {'type': 'spot',
#   'to_world': [[0.86696, 0.495844, -0.0501846, -0.748023],
#    [-0, 0.100696, 0.994917, 1938.12],
#    [0.498378, -0.862554, 0.0872994, 193.507],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot82': {'type': 'spot',
#   'to_world': [[0.963883, -0.263749, 0.0369699, -0.76523],
#    [0, 0.138814, 0.990319, 1966.79],
#    [-0.266327, -0.954551, 0.1338, 196.368],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot83': {'type': 'spot',
#   'to_world': [[0.859722, 0.509166, -0.0403334, -0.818309],
#    [-0, 0.0789671, 0.996877, 2054.29],
#    [0.510761, -0.857038, 0.0678898, 205.101],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot84': {'type': 'spot',
#   'to_world': [[0.874534, -0.48379, 0.0337287, -0.816619],
#    [0, 0.0695488, 0.997579, 2051.56],
#    [-0.484964, -0.872416, 0.0608228, 204.829],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot85': {'type': 'spot',
#   'to_world': [[0.999492, 0.031522, -0.00480051, -0.819736],
#    [-0, 0.150555, 0.988602, 2056.58],
#    [0.0318854, -0.988099, 0.150479, 205.331],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot86': {'type': 'spot',
#   'to_world': [[0.877234, -0.478869, 0.0338423, -0.831746],
#    [0, 0.0704955, 0.997512, 2075.93],
#    [-0.480064, -0.875051, 0.061841, 207.263],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot87': {'type': 'spot',
#   'to_world': [[0.989476, 0.14313, -0.0212386, -0.909499],
#    [-0, 0.14678, 0.989169, 2170.67],
#    [0.144697, -0.978759, 0.145235, 216.708],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot88': {'type': 'spot',
#   'to_world': [[0.986316, 0.163071, -0.0242676, -0.89986],
#    [-0, 0.147195, 0.989108, 2159.18],
#    [0.164867, -0.975572, 0.145181, 215.563],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot89': {'type': 'spot',
#   'to_world': [[0.943391, -0.328785, 0.0437521, -0.944052],
#    [0, 0.131909, 0.991262, 2211.83],
#    [-0.331684, -0.935147, 0.124442, 220.812],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot90': {'type': 'spot',
#   'to_world': [[0.860963, -0.506751, 0.0441079, -0.868058],
#    [0, 0.0867127, 0.996233, 2121.3],
#    [-0.508667, -0.85772, 0.0746565, 211.787],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot91': {'type': 'spot',
#   'to_world': [[0.999884, 0.0150392, -0.00227448, -0.944919],
#    [-0, 0.149536, 0.988756, 2212.86],
#    [0.0152103, -0.988642, 0.149519, 220.915],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot92': {'type': 'spot',
#   'to_world': [[0.995945, 0.0889541, -0.0134429, -0.980618],
#    [-0, 0.149425, 0.988773, 2255.39],
#    [0.0899641, -0.984764, 0.14882, 225.154],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot93': {'type': 'spot',
#   'to_world': [[0.910466, -0.410574, 0.049799, -0.981452],
#    [0, 0.120409, 0.992724, 2256.39],
#    [-0.413583, -0.903842, 0.109628, 225.253],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1},
#  'spot94': {'type': 'spot',
#   'to_world': [[0.882175, 0.468058, -0.0518631, -0.915087],
#    [-0, 0.110131, 0.993917, 2177.33],
#    [0.470922, -0.876809, 0.0971547, 217.372],
#    [0, 0, 0, 1]],
#   'intensity': {'type': 'spectrum', 'value': 2000},
#   'cutoff_angle': 1}}

# %%
# %%time
scenedict
scene = mi.load_dict(scenedict)
image = mi.render(scene)
plt.figure(figsize = (20,20))
plt.axis('off')
plt.imshow(image ** (1.0 / 2.2));
# Out:
# CPU times: user 7.26 s, sys: 440 ms, total: 7.7 s
# Wall time: 1.73 s
